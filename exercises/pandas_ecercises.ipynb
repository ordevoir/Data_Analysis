# %% [markdown]
# # Загрузка данных
#
# Функция `read_csv()` позволяет загрузку данных оп URL. Используйте данные Titanic:
#
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv

# %% [markdown]
# # Упражнения

# %% [markdown]
# Показать `head(10)`, `info()`, `describe(include="all")`.

# %% [markdown]
# Показать форму (shape) типы данных в колонках.

# %% [markdown]
# Построить гистограммы для age, fare (`bin=20`).

# %% [markdown]
# Отфильтруйте пассажиров: женщины старше 30 лет.

# %% [markdown]
# Для этой подвыборки посчитайте среднее по fare и долю выживших.

# %% [markdown]
# Посчитайте число пропусков по колонкам.

# %% [markdown]
# Удалите колонки с очень большим числом пропусков, например

# %% [markdown]
# Для осташихся колонок аполните пропуски медианами.

# %% [markdown]
# Проверьте новую форму датафрейма.
